# %%
# !pip3 install 'torch==0.3.1'
# !pip3 install 'tensorboardX'
# Out:
# Requirement already satisfied: torch==0.3.1 in /usr/local/lib/python3.6/dist-packages (0.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==0.3.1) (1.18.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from torch==0.3.1) (3.13)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (2.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (47.1.1)

# %%
# Load the Drive helper and mount
from google.colab import drive
import os
drive.mount('/content/drive')

path = 'drive/My Drive/ego-rnn/'
os.chdir(path)
cwd = os.getcwd()
print("Current dir: "+cwd)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current dir: /content/drive/My Drive/ego-rnn

# %%
from __future__ import print_function, division
from spatial_transforms import (Compose, ToTensor, CenterCrop, Scale, Normalize, MultiScaleCornerCrop,
 RandomHorizontalFlip)
from tensorboardX import SummaryWriter
import torch.nn as nn
from twoStreamModel import *
from torch.autograd import Variable
from torch.utils.data.sampler import WeightedRandomSampler
from makeDatasetTwoStream import *
import argparse

import sys

# %%
data_dir = "GTEA61/flow_x_processed"
user_train = ['S1','S3','S4']
user_val = ['S2']
out_dir = 'experiments'
seqLen = 25
trainBatchSize = 32
valBatchSize = 32
memSize = 512
num_classes = 61
frame = 5

flowModel='./experiments/flow/model_flow_state_dict.pth'
rgbModel='./experiments/rgb/ConvLSMT-Attention/16frames/stage2/model_rgb_state_dict.pth'

# %%
normalize = Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
spatial_transform = Compose([Scale(256), RandomHorizontalFlip(), MultiScaleCornerCrop([1, 0.875, 0.75, 0.65625], 224),
                              ToTensor(), normalize])

# %%
vid_seq_train = makeDataset(data_dir,user_train, spatial_transform=spatial_transform,
                               sequence=False, stackSize=frame, numSeg=1, fmt='.png', seqLen=seqLen)
train_loader = torch.utils.data.DataLoader(vid_seq_train, batch_size=trainBatchSize,
                            shuffle=True, num_workers=4, pin_memory=True)
vid_seq_val = makeDataset(data_dir,user_val, spatial_transform=Compose([Scale(256), CenterCrop(224), ToTensor(), normalize]),
                                   sequence=False, stackSize=frame, numSeg=1, fmt='.png', phase='Test',
                                   seqLen=seqLen)

val_loader = torch.utils.data.DataLoader(vid_seq_val, batch_size=valBatchSize,
                                shuffle=False, num_workers=2, pin_memory=True)

# %%
valInstances = vid_seq_val.__len__()
trainInstances = vid_seq_train.__len__()
print('Number of samples in the dataset: training = {} | validation = {}'.format(trainInstances, valInstances))
# Out:
# Number of samples in the dataset: training = 341 | validation = 116

# %%
numEpochs = 250
lr1 = 1e-2
decay_step =1
decay_factor = 0.99

# %%
model_folder = os.path.join('./', out_dir, 'twoStream16frm' )  # Dir for saving models and log files
# Create the dir
if os.path.exists(model_folder):
    print('Directory {} exists!'.format(model_folder))
    sys.exit()
os.makedirs(model_folder)

# Log files
writer = SummaryWriter(model_folder)
train_log_loss = open((model_folder + '/train_log_loss.txt'), 'w')
train_log_acc = open((model_folder + '/train_log_acc.txt'), 'w')
val_log_loss = open((model_folder + '/val_log_loss.txt'), 'w')
val_log_acc = open((model_folder + '/val_log_acc.txt'), 'w')

# %%
 model = twoStreamAttentionModel(flowModel=flowModel, frameModel=rgbModel, stackSize=frame,  memSize=memSize, num_classes=num_classes)

for params in model.parameters():
  params.requires_grad = False

model.train(False)
train_params = []

for params in model.classifier.parameters():
  params.requires_grad = True
  train_params += [params]

for params in model.frameModel.lstm_cell.parameters():
  train_params += [params]
  params.requires_grad = True

for params in model.frameModel.resNet.layer4[0].conv1.parameters():
  params.requires_grad = True
  train_params += [params]

for params in model.frameModel.resNet.layer4[0].conv2.parameters():
  params.requires_grad = True
  train_params += [params]

for params in model.frameModel.resNet.layer4[1].conv1.parameters():
  params.requires_grad = True
  train_params += [params]

for params in model.frameModel.resNet.layer4[1].conv2.parameters():
  params.requires_grad = True
  train_params += [params]

for params in model.frameModel.resNet.layer4[2].conv1.parameters():
  params.requires_grad = True
  train_params += [params]
    #
for params in model.frameModel.resNet.layer4[2].conv2.parameters():
  params.requires_grad = True
  train_params += [params]
    #
for params in model.frameModel.resNet.fc.parameters():
  params.requires_grad = True
  train_params += [params]

base_params = []
for params in model.flowModel.layer4.parameters():
  base_params += [params]
  params.requires_grad = True

model.cuda()
# Out:
# twoStreamAttentionModel(
#   (flowModel): ResNet(
#     (conv1): Conv2d(10, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1), ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (avgpool): AvgPool2d(kernel_size=7, stride=7, padding=0, ceil_mode=False, count_include_pad=True)
#     (dp): Dropout(p=0.5)
#     (fc_action): Linear(in_features=512, out_features=61, bias=True)
#   )
#   (frameModel): attentionModel(
#     (resNet): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
#       (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1), ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (4): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (5): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#           (relu): ReLU(inplace)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0, ceil_mode=False, count_include_pad=True)
#       (fc): Linear(in_features=512, out_features=1000, bias=True)
#     )
#     (lstm_cell): MyConvLSTMCell(
#       (conv_i_xx): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_i_hh): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_f_xx): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_f_hh): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_c_xx): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_c_hh): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_o_xx): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_o_hh): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (avgpool): AvgPool2d(kernel_size=7, stride=7, padding=0, ceil_mode=False, count_include_pad=True)
#     (dropout): Dropout(p=0.7)
#     (fc): Linear(in_features=512, out_features=61, bias=True)
#     (classifier): Sequential(
#       (0): Dropout(p=0.7)
#       (1): Linear(in_features=512, out_features=61, bias=True)
#     )
#   )
#   (fc2): Linear(in_features=1024, out_features=61, bias=True)
#   (dropout): Dropout(p=0.5)
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=1024, out_features=61, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer_fn = torch.optim.SGD([{'params': train_params},{'params': base_params, 'lr': 1e-4},], lr=lr1, momentum=0.9, weight_decay=5e-4)
optim_scheduler = torch.optim.lr_scheduler.StepLR(optimizer_fn, step_size=decay_step, gamma=decay_factor)
trainSamples = vid_seq_train.__len__()
valSamples=vid_seq_val.__len__()

# %%
train_iter = 0
min_accuracy = 0

for epoch in range(numEpochs):
  optim_scheduler.step()
  epoch_loss = 0
  numCorrTrain = 0
  iterPerEpoch = 0
  model.classifier.train(True)
  model.flowModel.layer4.train(True)
  for j, (inputFlow, inputFrame, targets) in enumerate(train_loader):
    train_iter += 1
    iterPerEpoch += 1
    optimizer_fn.zero_grad()
    inputVariableFlow = Variable(inputFlow.cuda())
    inputVariableFrame = Variable(inputFrame.permute(1, 0, 2, 3, 4).cuda())
    labelVariable = Variable(targets.cuda())
    output_label = model(inputVariableFlow, inputVariableFrame)
    loss = loss_fn(F.log_softmax(output_label, dim=1), labelVariable)
    loss.backward()
    optimizer_fn.step()
    _, predicted = torch.max(output_label.data, 1)
    numCorrTrain += (predicted == targets.cuda()).sum()
    epoch_loss += loss.data[0]
  avg_loss = epoch_loss / iterPerEpoch
  trainAccuracy = (numCorrTrain / trainSamples) * 100
  print('Average training loss after {} epoch = {} '.format(epoch + 1, avg_loss))
  print('Training accuracy after {} epoch = {}% '.format(epoch + 1, trainAccuracy))
  writer.add_scalar('train/epoch_loss', avg_loss, epoch + 1)
  writer.add_scalar('train/accuracy', trainAccuracy, epoch + 1)
  train_log_loss.write('Training loss after {} epoch = {}\n'.format(epoch + 1, avg_loss))
  train_log_acc.write('Training accuracy after {} epoch = {}\n'.format(epoch + 1, trainAccuracy))    
  if (epoch + 1) % 1 == 0:
    model.train(False)
    val_loss_epoch = 0
    val_iter = 0
    numCorr = 0
    for j, (inputFlow, inputFrame, targets) in enumerate(val_loader):
       val_iter += 1
       inputVariableFlow = Variable(inputFlow.cuda())
       inputVariableFrame = Variable(inputFrame.permute(1, 0, 2, 3, 4).cuda())
       labelVariable = Variable(targets.cuda())
       output_label = model(inputVariableFlow, inputVariableFrame)
       loss = loss_fn(F.log_softmax(output_label, dim=1), labelVariable)
       val_loss_epoch += loss.data[0]
       _, predicted = torch.max(output_label.data, 1)
       numCorr += (predicted == labelVariable.data).sum()
    val_accuracy = (numCorr / valSamples) * 100
    avg_val_loss = val_loss_epoch / val_iter
    print('Val Loss after {} epochs, loss = {}'.format(epoch + 1, avg_val_loss))
    print('Val Accuracy after {} epochs = {}%'.format(epoch + 1, val_accuracy))
    writer.add_scalar('val/epoch_loss', avg_val_loss, epoch + 1)
    writer.add_scalar('val/accuracy', val_accuracy, epoch + 1)
    val_log_loss.write('Val Loss after {} epochs = {}\n'.format(epoch + 1, avg_val_loss))
    val_log_acc.write('Val Accuracy after {} epochs = {}%\n'.format(epoch + 1, val_accuracy))
    if val_accuracy > min_accuracy:
      save_path_model = (model_folder + '/model_twoStream_state_dict.pth')
      torch.save(model.state_dict(), save_path_model)
      min_accuracy = val_accuracy
train_log_loss.close()
train_log_acc.close()
val_log_acc.close()
val_log_loss.close()
writer.export_scalars_to_json(model_folder + "/all_scalars.json")
writer.close()
# Out:
# Average training loss after 1 epoch = 3.6909544467926025
# Training accuracy after 1 epoch = 16.129032258064516%
# Val Loss after 1 epochs, loss = 2.837019383907318
# Val Accuracy after 1 epochs = 24.137931034482758%
# Average training loss after 2 epoch = 2.302162755619396
# Training accuracy after 2 epoch = 39.589442815249264%
# Val Loss after 2 epochs, loss = 2.309513747692108
# Val Accuracy after 2 epochs = 43.96551724137931%
# Average training loss after 3 epoch = 1.9724411856044421
# Training accuracy after 3 epoch = 48.09384164222874%
# Val Loss after 3 epochs, loss = 1.8431525528430939
# Val Accuracy after 3 epochs = 48.275862068965516%
# Average training loss after 4 epoch = 1.6041024814952503
# Training accuracy after 4 epoch = 56.598240469208214%
# Val Loss after 4 epochs, loss = 1.8304044306278229
# Val Accuracy after 4 epochs = 48.275862068965516%
# Average training loss after 5 epoch = 1.353655148636211
# Training accuracy after 5 epoch = 66.27565982404691%
# Val Loss after 5 epochs, loss = 1.8523720502853394
# Val Accuracy after 5 epochs = 52.58620689655172%
# Average training loss after 6 epoch = 1.212797387079759
# Training accuracy after 6 epoch = 69.20821114369502%
# Val Loss after 6 epochs, loss = 1.8506014943122864
# Val Accuracy after 6 epochs = 56.03448275862068%
# Average training loss after 7 epoch = 0.9585012143308466
# Training accuracy after 7 epoch = 74.48680351906158%
# Val Loss after 7 epochs, loss = 1.7964217960834503
# Val Accuracy after 7 epochs = 49.137931034482754%
# Average training loss after 8 epoch = 0.9159593907269564
# Training accuracy after 8 epoch = 75.0733137829912%
# Val Loss after 8 epochs, loss = 1.7981115281581879
# Val Accuracy after 8 epochs = 50.0%
# Average training loss after 9 epoch = 0.8216466145081953
# Training accuracy after 9 epoch = 77.71260997067448%
# Val Loss after 9 epochs, loss = 1.7903029918670654
# Val Accuracy after 9 epochs = 50.0%
# Average training loss after 10 epoch = 0.8754093863747336
# Training accuracy after 10 epoch = 76.83284457478005%
# Val Loss after 10 epochs, loss = 1.6905365586280823
# Val Accuracy after 10 epochs = 56.896551724137936%
# Average training loss after 11 epoch = 0.7854226502505216
# Training accuracy after 11 epoch = 78.88563049853371%
# Val Loss after 11 epochs, loss = 1.8830778896808624
# Val Accuracy after 11 epochs = 55.172413793103445%
# Average training loss after 12 epoch = 0.6459079384803772
# Training accuracy after 12 epoch = 82.11143695014663%
# Val Loss after 12 epochs, loss = 1.730398714542389
# Val Accuracy after 12 epochs = 53.44827586206896%
# Average training loss after 13 epoch = 0.7628662640398199
# Training accuracy after 13 epoch = 77.41935483870968%
# Val Loss after 13 epochs, loss = 1.6441422402858734
# Val Accuracy after 13 epochs = 59.48275862068966%
# Average training loss after 14 epoch = 0.6922181438315999
# Training accuracy after 14 epoch = 79.47214076246334%
# Val Loss after 14 epochs, loss = 1.665212720632553
# Val Accuracy after 14 epochs = 60.3448275862069%
# Average training loss after 15 epoch = 0.7158359749750658
# Training accuracy after 15 epoch = 80.64516129032258%
# Val Loss after 15 epochs, loss = 1.5312305092811584
# Val Accuracy after 15 epochs = 62.06896551724138%
# Average training loss after 16 epoch = 0.7784845287149603
# Training accuracy after 16 epoch = 80.05865102639295%
# Val Loss after 16 epochs, loss = 1.7336706519126892
# Val Accuracy after 16 epochs = 59.48275862068966%
# Average training loss after 17 epoch = 0.7838194370269775
# Training accuracy after 17 epoch = 77.41935483870968%
# Val Loss after 17 epochs, loss = 1.656015694141388
# Val Accuracy after 17 epochs = 58.620689655172406%
# Average training loss after 18 epoch = 0.5885876308787953
# Training accuracy after 18 epoch = 84.1642228739003%
# Val Loss after 18 epochs, loss = 1.628390371799469
# Val Accuracy after 18 epochs = 56.896551724137936%
# Average training loss after 19 epoch = 0.5963118672370911
# Training accuracy after 19 epoch = 82.69794721407625%
# Val Loss after 19 epochs, loss = 1.6927536725997925
# Val Accuracy after 19 epochs = 57.758620689655174%
# Average training loss after 20 epoch = 0.6434766270897605
# Training accuracy after 20 epoch = 82.11143695014663%
# Val Loss after 20 epochs, loss = 1.6461340188980103
# Val Accuracy after 20 epochs = 58.620689655172406%
# Average training loss after 21 epoch = 0.6748592961918224
# Training accuracy after 21 epoch = 81.23167155425219%
# Val Loss after 21 epochs, loss = 1.7316676378250122
# Val Accuracy after 21 epochs = 52.58620689655172%
# Average training loss after 22 epoch = 0.6713836599480022
# Training accuracy after 22 epoch = 79.47214076246334%
# Val Loss after 22 epochs, loss = 1.888503611087799
# Val Accuracy after 22 epochs = 55.172413793103445%
# Average training loss after 23 epoch = 0.5768205686049028
# Training accuracy after 23 epoch = 83.28445747800586%
# Val Loss after 23 epochs, loss = 1.8009041249752045
# Val Accuracy after 23 epochs = 57.758620689655174%
# Average training loss after 24 epoch = 0.5455819476734508
# Training accuracy after 24 epoch = 85.92375366568915%
# Val Loss after 24 epochs, loss = 1.825282484292984
# Val Accuracy after 24 epochs = 60.3448275862069%
# Average training loss after 25 epoch = 0.5509656071662903
# Training accuracy after 25 epoch = 84.4574780058651%
# Val Loss after 25 epochs, loss = 1.8372453451156616
# Val Accuracy after 25 epochs = 59.48275862068966%
# Average training loss after 26 epoch = 0.5035496191544966
# Training accuracy after 26 epoch = 85.04398826979472%
# Val Loss after 26 epochs, loss = 2.067275822162628
# Val Accuracy after 26 epochs = 53.44827586206896%
# Average training loss after 27 epoch = 0.516301607543772
# Training accuracy after 27 epoch = 84.75073313782991%
# Val Loss after 27 epochs, loss = 1.8158175945281982
# Val Accuracy after 27 epochs = 56.03448275862068%
# Average training loss after 28 epoch = 0.5580750161951239
# Training accuracy after 28 epoch = 83.87096774193549%
# Val Loss after 28 epochs, loss = 1.6677853018045425
# Val Accuracy after 28 epochs = 62.06896551724138%
# Average training loss after 29 epoch = 0.46374912559986115
# Training accuracy after 29 epoch = 87.09677419354838%
# Val Loss after 29 epochs, loss = 1.66329787671566
# Val Accuracy after 29 epochs = 62.06896551724138%
# Average training loss after 30 epoch = 0.487225895578211
# Training accuracy after 30 epoch = 85.92375366568915%
# Val Loss after 30 epochs, loss = 1.6076193749904633
# Val Accuracy after 30 epochs = 60.3448275862069%
# Average training loss after 31 epoch = 0.4285181842067025
# Training accuracy after 31 epoch = 88.26979472140762%
# Val Loss after 31 epochs, loss = 1.878577470779419
# Val Accuracy after 31 epochs = 56.896551724137936%
# Average training loss after 32 epoch = 0.48148326304825867
# Training accuracy after 32 epoch = 85.33724340175954%
# Val Loss after 32 epochs, loss = 1.7088135033845901
# Val Accuracy after 32 epochs = 56.03448275862068%
# Average training loss after 33 epoch = 0.43408291177316144
# Training accuracy after 33 epoch = 86.21700879765396%
# Val Loss after 33 epochs, loss = 1.7572027146816254
# Val Accuracy after 33 epochs = 61.206896551724135%
# Average training loss after 34 epoch = 0.5470438626679507
# Training accuracy after 34 epoch = 82.69794721407625%
# Val Loss after 34 epochs, loss = 1.785467579960823
# Val Accuracy after 34 epochs = 55.172413793103445%
# Average training loss after 35 epoch = 0.587275358763608
# Training accuracy after 35 epoch = 83.28445747800586%
# Val Loss after 35 epochs, loss = 1.8966337144374847
# Val Accuracy after 35 epochs = 59.48275862068966%
# Average training loss after 36 epoch = 0.5275694714351133
# Training accuracy after 36 epoch = 84.1642228739003%
# Val Loss after 36 epochs, loss = 1.7347457855939865
# Val Accuracy after 36 epochs = 62.06896551724138%
# Average training loss after 37 epoch = 0.48935244300148706
# Training accuracy after 37 epoch = 84.75073313782991%
# Val Loss after 37 epochs, loss = 1.8163464069366455
# Val Accuracy after 37 epochs = 63.793103448275865%
# Average training loss after 38 epoch = 0.53317622163079
# Training accuracy after 38 epoch = 85.92375366568915%
# Val Loss after 38 epochs, loss = 1.5947927087545395
# Val Accuracy after 38 epochs = 62.93103448275862%
# Average training loss after 39 epoch = 0.4454336613416672
# Training accuracy after 39 epoch = 87.3900293255132%
# Val Loss after 39 epochs, loss = 1.6868721395730972
# Val Accuracy after 39 epochs = 58.620689655172406%
# Average training loss after 40 epoch = 0.4932279058478095
# Training accuracy after 40 epoch = 87.09677419354838%
# Val Loss after 40 epochs, loss = 1.6702178418636322
# Val Accuracy after 40 epochs = 58.620689655172406%
# Average training loss after 41 epoch = 0.5245158293030479
# Training accuracy after 41 epoch = 85.04398826979472%
# Val Loss after 41 epochs, loss = 1.7599521279335022
# Val Accuracy after 41 epochs = 54.310344827586206%
# Average training loss after 42 epoch = 0.5365589369427074
# Training accuracy after 42 epoch = 83.87096774193549%
# Val Loss after 42 epochs, loss = 1.7646624743938446
# Val Accuracy after 42 epochs = 56.896551724137936%
# Average training loss after 43 epoch = 0.4112019484693354
# Training accuracy after 43 epoch = 87.09677419354838%
# Val Loss after 43 epochs, loss = 1.694571703672409
# Val Accuracy after 43 epochs = 60.3448275862069%
# Average training loss after 44 epoch = 0.4005284864794124
# Training accuracy after 44 epoch = 85.92375366568915%
# Val Loss after 44 epochs, loss = 1.6520060896873474
# Val Accuracy after 44 epochs = 59.48275862068966%
# Average training loss after 45 epoch = 0.45488164641640405
# Training accuracy after 45 epoch = 85.33724340175954%
# Val Loss after 45 epochs, loss = 1.7022267878055573
# Val Accuracy after 45 epochs = 61.206896551724135%
# Average training loss after 46 epoch = 0.41142851927063684
# Training accuracy after 46 epoch = 86.80351906158357%
# Val Loss after 46 epochs, loss = 1.5849315822124481
# Val Accuracy after 46 epochs = 60.3448275862069%
# Average training loss after 47 epoch = 0.39208331162279303
# Training accuracy after 47 epoch = 85.92375366568915%
# Val Loss after 47 epochs, loss = 1.594159871339798
# Val Accuracy after 47 epochs = 63.793103448275865%
# Average training loss after 48 epoch = 0.40802461992610584
# Training accuracy after 48 epoch = 87.97653958944281%
# Val Loss after 48 epochs, loss = 1.7878647446632385
# Val Accuracy after 48 epochs = 58.620689655172406%
# Average training loss after 49 epoch = 0.4451740248636766
# Training accuracy after 49 epoch = 87.68328445747801%
# Val Loss after 49 epochs, loss = 1.7852899730205536
# Val Accuracy after 49 epochs = 57.758620689655174%
# Average training loss after 50 epoch = 0.3719304691661488
# Training accuracy after 50 epoch = 89.44281524926686%
# Val Loss after 50 epochs, loss = 1.8460011780261993
# Val Accuracy after 50 epochs = 56.896551724137936%
# Average training loss after 51 epoch = 0.4470174718986858
# Training accuracy after 51 epoch = 88.26979472140762%
# Val Loss after 51 epochs, loss = 1.7645576298236847
# Val Accuracy after 51 epochs = 61.206896551724135%
# Average training loss after 52 epoch = 0.43039870126680896
# Training accuracy after 52 epoch = 88.56304985337243%
# Val Loss after 52 epochs, loss = 1.8796470165252686
# Val Accuracy after 52 epochs = 57.758620689655174%
# Average training loss after 53 epoch = 0.3760105642405423
# Training accuracy after 53 epoch = 87.68328445747801%
# Val Loss after 53 epochs, loss = 1.8109671771526337
# Val Accuracy after 53 epochs = 56.896551724137936%
# Average training loss after 54 epoch = 0.44742248545993457
# Training accuracy after 54 epoch = 88.85630498533725%
# Val Loss after 54 epochs, loss = 2.0802489519119263
# Val Accuracy after 54 epochs = 53.44827586206896%
# Average training loss after 55 epoch = 0.43588948385281995
# Training accuracy after 55 epoch = 85.92375366568915%
# Val Loss after 55 epochs, loss = 1.732407569885254
# Val Accuracy after 55 epochs = 57.758620689655174%
# Average training loss after 56 epoch = 0.3671454746614803
# Training accuracy after 56 epoch = 88.26979472140762%
# Val Loss after 56 epochs, loss = 1.711644023656845
# Val Accuracy after 56 epochs = 59.48275862068966%
# Average training loss after 57 epoch = 0.437063993378119
# Training accuracy after 57 epoch = 87.68328445747801%
# Val Loss after 57 epochs, loss = 1.704332560300827
# Val Accuracy after 57 epochs = 59.48275862068966%
# Average training loss after 58 epoch = 0.46520885825157166
# Training accuracy after 58 epoch = 83.28445747800586%
# Val Loss after 58 epochs, loss = 1.9570228457450867
# Val Accuracy after 58 epochs = 57.758620689655174%
# Average training loss after 59 epoch = 0.41399112885648554
# Training accuracy after 59 epoch = 88.56304985337243%
# Val Loss after 59 epochs, loss = 1.701306700706482
# Val Accuracy after 59 epochs = 62.06896551724138%
# Average training loss after 60 epoch = 0.340003256093372
# Training accuracy after 60 epoch = 88.56304985337243%
# Val Loss after 60 epochs, loss = 1.7990557253360748
# Val Accuracy after 60 epochs = 60.3448275862069%
# Average training loss after 61 epoch = 0.41003319824283774
# Training accuracy after 61 epoch = 88.56304985337243%
# Val Loss after 61 epochs, loss = 1.5596142411231995
# Val Accuracy after 61 epochs = 64.65517241379311%
# Average training loss after 62 epoch = 0.31029695069248026
# Training accuracy after 62 epoch = 91.20234604105572%
# Val Loss after 62 epochs, loss = 1.520859032869339
# Val Accuracy after 62 epochs = 63.793103448275865%
# Average training loss after 63 epoch = 0.39774165099317377
# Training accuracy after 63 epoch = 89.14956011730204%
# Val Loss after 63 epochs, loss = 1.5334546864032745
# Val Accuracy after 63 epochs = 62.06896551724138%
# Average training loss after 64 epoch = 0.4383495402607051
# Training accuracy after 64 epoch = 86.51026392961877%
# Val Loss after 64 epochs, loss = 1.6833791434764862
# Val Accuracy after 64 epochs = 58.620689655172406%
# Average training loss after 65 epoch = 0.4372026974504644
# Training accuracy after 65 epoch = 87.68328445747801%
# Val Loss after 65 epochs, loss = 1.8040832579135895
# Val Accuracy after 65 epochs = 63.793103448275865%
# Average training loss after 66 epoch = 0.40934526513923297
# Training accuracy after 66 epoch = 87.97653958944281%
# Val Loss after 66 epochs, loss = 1.6919159889221191
# Val Accuracy after 66 epochs = 63.793103448275865%
# Average training loss after 67 epoch = 0.42402523214166815
# Training accuracy after 67 epoch = 88.26979472140762%
# Val Loss after 67 epochs, loss = 1.761581689119339
# Val Accuracy after 67 epochs = 62.93103448275862%
# Average training loss after 68 epoch = 0.39739955826239154
# Training accuracy after 68 epoch = 87.68328445747801%
# Val Loss after 68 epochs, loss = 1.6851012408733368
# Val Accuracy after 68 epochs = 59.48275862068966%
# Average training loss after 69 epoch = 0.3773880749940872
# Training accuracy after 69 epoch = 88.85630498533725%
# Val Loss after 69 epochs, loss = 1.8146993517875671
# Val Accuracy after 69 epochs = 58.620689655172406%
# Average training loss after 70 epoch = 0.3869325843724338
# Training accuracy after 70 epoch = 87.09677419354838%
# Val Loss after 70 epochs, loss = 1.694197565317154
# Val Accuracy after 70 epochs = 60.3448275862069%
# Average training loss after 71 epoch = 0.3381470915946094
# Training accuracy after 71 epoch = 90.32258064516128%
# Val Loss after 71 epochs, loss = 1.7834740281105042
# Val Accuracy after 71 epochs = 58.620689655172406%
# Average training loss after 72 epoch = 0.3315101347186349
# Training accuracy after 72 epoch = 88.85630498533725%
# Val Loss after 72 epochs, loss = 1.75427708029747
# Val Accuracy after 72 epochs = 62.93103448275862%
# Average training loss after 73 epoch = 0.30002624880183826
# Training accuracy after 73 epoch = 91.78885630498533%
# Val Loss after 73 epochs, loss = 1.7451642453670502
# Val Accuracy after 73 epochs = 58.620689655172406%
# Average training loss after 74 epoch = 0.3701367039572109
# Training accuracy after 74 epoch = 89.73607038123167%
# Val Loss after 74 epochs, loss = 1.71499964594841
# Val Accuracy after 74 epochs = 65.51724137931035%
# Average training loss after 75 epoch = 0.29904983937740326
# Training accuracy after 75 epoch = 91.49560117302052%
# Val Loss after 75 epochs, loss = 1.6927489042282104
# Val Accuracy after 75 epochs = 60.3448275862069%
# Average training loss after 76 epoch = 0.31848331269892777
# Training accuracy after 76 epoch = 89.14956011730204%
# Val Loss after 76 epochs, loss = 1.6249480545520782
# Val Accuracy after 76 epochs = 60.3448275862069%
# Average training loss after 77 epoch = 0.3462423330003565
# Training accuracy after 77 epoch = 89.44281524926686%
# Val Loss after 77 epochs, loss = 1.5082763731479645
# Val Accuracy after 77 epochs = 62.93103448275862%
# Average training loss after 78 epoch = 0.33774145624854346
# Training accuracy after 78 epoch = 90.9090909090909%
# Val Loss after 78 epochs, loss = 1.5443857908248901
# Val Accuracy after 78 epochs = 64.65517241379311%
# Average training loss after 79 epoch = 0.35139085623351013
# Training accuracy after 79 epoch = 88.85630498533725%
# Val Loss after 79 epochs, loss = 1.683114618062973
# Val Accuracy after 79 epochs = 62.93103448275862%
# Average training loss after 80 epoch = 0.27924684435129166
# Training accuracy after 80 epoch = 94.13489736070382%
# Val Loss after 80 epochs, loss = 1.6119355261325836
# Val Accuracy after 80 epochs = 61.206896551724135%
# Average training loss after 81 epoch = 0.30695644833824853
# Training accuracy after 81 epoch = 90.02932551319648%
# Val Loss after 81 epochs, loss = 1.5535444617271423
# Val Accuracy after 81 epochs = 63.793103448275865%
# Average training loss after 82 epoch = 0.2775935706767169
# Training accuracy after 82 epoch = 90.02932551319648%
# Val Loss after 82 epochs, loss = 1.4926427602767944
# Val Accuracy after 82 epochs = 63.793103448275865%
# Average training loss after 83 epoch = 0.36568908393383026
# Training accuracy after 83 epoch = 89.44281524926686%
# Val Loss after 83 epochs, loss = 1.5143169164657593
# Val Accuracy after 83 epochs = 62.93103448275862%
# Average training loss after 84 epoch = 0.3560114120217887
# Training accuracy after 84 epoch = 88.85630498533725%
# Val Loss after 84 epochs, loss = 1.4870153665542603
# Val Accuracy after 84 epochs = 62.93103448275862%
# Average training loss after 85 epoch = 0.27568076009100134
# Training accuracy after 85 epoch = 92.37536656891496%
# Val Loss after 85 epochs, loss = 1.3987618386745453
# Val Accuracy after 85 epochs = 65.51724137931035%
# Average training loss after 86 epoch = 0.3036392331123352
# Training accuracy after 86 epoch = 91.20234604105572%
# Val Loss after 86 epochs, loss = 1.4053643643856049
# Val Accuracy after 86 epochs = 64.65517241379311%
# Average training loss after 87 epoch = 0.29492478479038586
# Training accuracy after 87 epoch = 91.49560117302052%
# Val Loss after 87 epochs, loss = 1.4031932353973389
# Val Accuracy after 87 epochs = 64.65517241379311%
# Average training loss after 88 epoch = 0.31385696882551367
# Training accuracy after 88 epoch = 88.26979472140762%
# Val Loss after 88 epochs, loss = 1.5874934196472168
# Val Accuracy after 88 epochs = 60.3448275862069%
# Average training loss after 89 epoch = 0.3153085776350715
# Training accuracy after 89 epoch = 90.32258064516128%
# Val Loss after 89 epochs, loss = 1.5967643558979034
# Val Accuracy after 89 epochs = 63.793103448275865%
# Average training loss after 90 epoch = 0.2731820439750498
# Training accuracy after 90 epoch = 92.66862170087975%
# Val Loss after 90 epochs, loss = 1.8650937378406525
# Val Accuracy after 90 epochs = 58.620689655172406%
# Average training loss after 91 epoch = 0.34952930157834833
# Training accuracy after 91 epoch = 88.26979472140762%
# Val Loss after 91 epochs, loss = 1.501079648733139
# Val Accuracy after 91 epochs = 64.65517241379311%
# Average training loss after 92 epoch = 0.28719413686882367
# Training accuracy after 92 epoch = 90.6158357771261%
# Val Loss after 92 epochs, loss = 1.432673066854477
# Val Accuracy after 92 epochs = 64.65517241379311%
# Average training loss after 93 epoch = 0.2824588431553407
# Training accuracy after 93 epoch = 92.08211143695014%
# Val Loss after 93 epochs, loss = 1.4488091617822647
# Val Accuracy after 93 epochs = 65.51724137931035%
# Average training loss after 94 epoch = 0.33049785007130017
# Training accuracy after 94 epoch = 88.26979472140762%
# Val Loss after 94 epochs, loss = 1.6594682335853577
# Val Accuracy after 94 epochs = 64.65517241379311%
# Average training loss after 95 epoch = 0.29061697084795346
# Training accuracy after 95 epoch = 92.66862170087975%
# Val Loss after 95 epochs, loss = 1.538633480668068
# Val Accuracy after 95 epochs = 63.793103448275865%
# Average training loss after 96 epoch = 0.3991286971352317
# Training accuracy after 96 epoch = 88.26979472140762%
# Val Loss after 96 epochs, loss = 1.5761514902114868
# Val Accuracy after 96 epochs = 61.206896551724135%
# Average training loss after 97 epoch = 0.297985315322876
# Training accuracy after 97 epoch = 90.6158357771261%
# Val Loss after 97 epochs, loss = 1.68876451253891
# Val Accuracy after 97 epochs = 67.24137931034483%
# Average training loss after 98 epoch = 0.29702769219875336
# Training accuracy after 98 epoch = 90.9090909090909%
# Val Loss after 98 epochs, loss = 1.5226028114557266
# Val Accuracy after 98 epochs = 65.51724137931035%
# Average training loss after 99 epoch = 0.2967695878310637
# Training accuracy after 99 epoch = 90.32258064516128%
# Val Loss after 99 epochs, loss = 1.4357997179031372
# Val Accuracy after 99 epochs = 65.51724137931035%
# Average training loss after 100 epoch = 0.3205831470814618
# Training accuracy after 100 epoch = 89.73607038123167%
# Val Loss after 100 epochs, loss = 1.487368032336235
# Val Accuracy after 100 epochs = 65.51724137931035%
# Average training loss after 101 epoch = 0.27977529439059173
# Training accuracy after 101 epoch = 90.32258064516128%
# Val Loss after 101 epochs, loss = 1.5318934172391891
# Val Accuracy after 101 epochs = 63.793103448275865%
# Average training loss after 102 epoch = 0.27024106749079446
# Training accuracy after 102 epoch = 90.9090909090909%
# Val Loss after 102 epochs, loss = 1.5756977051496506
# Val Accuracy after 102 epochs = 63.793103448275865%
# Average training loss after 103 epoch = 0.1829648952592503
# Training accuracy after 103 epoch = 94.72140762463343%
# Val Loss after 103 epochs, loss = 1.5533400177955627
# Val Accuracy after 103 epochs = 66.37931034482759%
# Average training loss after 104 epoch = 0.29148025065660477
# Training accuracy after 104 epoch = 90.6158357771261%
# Val Loss after 104 epochs, loss = 1.557232677936554
# Val Accuracy after 104 epochs = 67.24137931034483%
# Average training loss after 105 epoch = 0.25805771486325696
# Training accuracy after 105 epoch = 92.66862170087975%
# Val Loss after 105 epochs, loss = 1.7172676026821136
# Val Accuracy after 105 epochs = 62.93103448275862%
# Average training loss after 106 epoch = 0.26529055359688675
# Training accuracy after 106 epoch = 91.78885630498533%
# Val Loss after 106 epochs, loss = 1.6115412414073944
# Val Accuracy after 106 epochs = 66.37931034482759%
# Average training loss after 107 epoch = 0.1961623193188147
# Training accuracy after 107 epoch = 92.96187683284457%
# Val Loss after 107 epochs, loss = 1.5865310728549957
# Val Accuracy after 107 epochs = 64.65517241379311%
# Average training loss after 108 epoch = 0.2261396355249665
# Training accuracy after 108 epoch = 93.25513196480938%
# Val Loss after 108 epochs, loss = 1.4742026180028915
# Val Accuracy after 108 epochs = 68.96551724137932%
# Average training loss after 109 epoch = 0.324476034803824
# Training accuracy after 109 epoch = 89.14956011730204%
# Val Loss after 109 epochs, loss = 1.5458577573299408
# Val Accuracy after 109 epochs = 66.37931034482759%
# Average training loss after 110 epoch = 0.20989830859682776
# Training accuracy after 110 epoch = 94.42815249266863%
# Val Loss after 110 epochs, loss = 1.5991461873054504
# Val Accuracy after 110 epochs = 64.65517241379311%
# Average training loss after 111 epoch = 0.2764016870747913
# Training accuracy after 111 epoch = 92.37536656891496%
# Val Loss after 111 epochs, loss = 1.5653793066740036
# Val Accuracy after 111 epochs = 68.96551724137932%
# Average training loss after 112 epoch = 0.2985962128097361
# Training accuracy after 112 epoch = 90.32258064516128%
# Val Loss after 112 epochs, loss = 1.6010158509016037
# Val Accuracy after 112 epochs = 65.51724137931035%
# Average training loss after 113 epoch = 0.26224627278067847
# Training accuracy after 113 epoch = 92.37536656891496%
# Val Loss after 113 epochs, loss = 1.556138351559639
# Val Accuracy after 113 epochs = 67.24137931034483%
# Average training loss after 114 epoch = 0.2851869775490327
# Training accuracy after 114 epoch = 92.08211143695014%
# Val Loss after 114 epochs, loss = 1.6341266483068466
# Val Accuracy after 114 epochs = 62.93103448275862%
# Average training loss after 115 epoch = 0.3101345056837255
# Training accuracy after 115 epoch = 90.9090909090909%
# Val Loss after 115 epochs, loss = 1.625647559762001
# Val Accuracy after 115 epochs = 65.51724137931035%
# Average training loss after 116 epoch = 0.2979206862774762
# Training accuracy after 116 epoch = 91.20234604105572%
# Val Loss after 116 epochs, loss = 1.507048711180687
# Val Accuracy after 116 epochs = 65.51724137931035%
# Average training loss after 117 epoch = 0.247325983914462
# Training accuracy after 117 epoch = 92.96187683284457%
# Val Loss after 117 epochs, loss = 1.480942726135254
# Val Accuracy after 117 epochs = 68.96551724137932%
# Average training loss after 118 epoch = 0.3000177077271722
# Training accuracy after 118 epoch = 90.02932551319648%
# Val Loss after 118 epochs, loss = 1.528357371687889
# Val Accuracy after 118 epochs = 65.51724137931035%
# Average training loss after 119 epoch = 0.26206515661694785
# Training accuracy after 119 epoch = 91.78885630498533%
# Val Loss after 119 epochs, loss = 1.6744418144226074
# Val Accuracy after 119 epochs = 65.51724137931035%
# Average training loss after 120 epoch = 0.28452872518788686
# Training accuracy after 120 epoch = 92.08211143695014%
# Val Loss after 120 epochs, loss = 1.6652695089578629
# Val Accuracy after 120 epochs = 64.65517241379311%
# Average training loss after 121 epoch = 0.23743206127123398
# Training accuracy after 121 epoch = 92.37536656891496%
# Val Loss after 121 epochs, loss = 1.5316323339939117
# Val Accuracy after 121 epochs = 65.51724137931035%
# Average training loss after 122 epoch = 0.24342002787373282
# Training accuracy after 122 epoch = 92.37536656891496%
# Val Loss after 122 epochs, loss = 1.4402213394641876
# Val Accuracy after 122 epochs = 65.51724137931035%
# Average training loss after 123 epoch = 0.3117783570831472
# Training accuracy after 123 epoch = 90.6158357771261%
# Val Loss after 123 epochs, loss = 1.6020981669425964
# Val Accuracy after 123 epochs = 62.93103448275862%
# Average training loss after 124 epoch = 0.2754657275297425
# Training accuracy after 124 epoch = 92.37536656891496%
# Val Loss after 124 epochs, loss = 1.501367300748825
# Val Accuracy after 124 epochs = 65.51724137931035%
# Average training loss after 125 epoch = 0.2600138092582876
# Training accuracy after 125 epoch = 90.32258064516128%
# Val Loss after 125 epochs, loss = 1.3782643377780914
# Val Accuracy after 125 epochs = 65.51724137931035%
# Average training loss after 126 epoch = 0.2542701851237904
# Training accuracy after 126 epoch = 91.49560117302052%
# Val Loss after 126 epochs, loss = 1.396821066737175
# Val Accuracy after 126 epochs = 65.51724137931035%
# Average training loss after 127 epoch = 0.2331607233394276
# Training accuracy after 127 epoch = 92.08211143695014%
# Val Loss after 127 epochs, loss = 1.4187965393066406
# Val Accuracy after 127 epochs = 66.37931034482759%
# Average training loss after 128 epoch = 0.2750124748457562
# Training accuracy after 128 epoch = 90.9090909090909%
# Val Loss after 128 epochs, loss = 1.4718413949012756
# Val Accuracy after 128 epochs = 67.24137931034483%
# Average training loss after 129 epoch = 0.29321367835456674
# Training accuracy after 129 epoch = 90.9090909090909%
# Val Loss after 129 epochs, loss = 1.525104120373726
# Val Accuracy after 129 epochs = 65.51724137931035%
# Average training loss after 130 epoch = 0.2364940054037354
# Training accuracy after 130 epoch = 92.37536656891496%
# Val Loss after 130 epochs, loss = 1.5009107440710068
# Val Accuracy after 130 epochs = 66.37931034482759%
# Average training loss after 131 epoch = 0.3357103426348079
# Training accuracy after 131 epoch = 90.6158357771261%
# Val Loss after 131 epochs, loss = 1.564485341310501
# Val Accuracy after 131 epochs = 62.93103448275862%
# Average training loss after 132 epoch = 0.22417409243908795
# Training accuracy after 132 epoch = 93.54838709677419%
# Val Loss after 132 epochs, loss = 1.5356212705373764
# Val Accuracy after 132 epochs = 63.793103448275865%
# Average training loss after 133 epoch = 0.23920243301174857
# Training accuracy after 133 epoch = 93.25513196480938%
# Val Loss after 133 epochs, loss = 1.5079037547111511
# Val Accuracy after 133 epochs = 66.37931034482759%
# Average training loss after 134 epoch = 0.2834697270935232
# Training accuracy after 134 epoch = 91.78885630498533%
# Val Loss after 134 epochs, loss = 1.5265422314405441
# Val Accuracy after 134 epochs = 63.793103448275865%
# Average training loss after 135 epoch = 0.2697044082663276
# Training accuracy after 135 epoch = 91.20234604105572%
# Val Loss after 135 epochs, loss = 1.5356363654136658
# Val Accuracy after 135 epochs = 66.37931034482759%
# Average training loss after 136 epoch = 0.20279977538368918
# Training accuracy after 136 epoch = 93.25513196480938%
# Val Loss after 136 epochs, loss = 1.5595313906669617
# Val Accuracy after 136 epochs = 69.82758620689656%
# Average training loss after 137 epoch = 0.23978505148129028
# Training accuracy after 137 epoch = 93.54838709677419%
# Val Loss after 137 epochs, loss = 1.4091689735651016
# Val Accuracy after 137 epochs = 68.96551724137932%
# Average training loss after 138 epoch = 0.21006064997477966
# Training accuracy after 138 epoch = 94.72140762463343%
# Val Loss after 138 epochs, loss = 1.4727822989225388
# Val Accuracy after 138 epochs = 67.24137931034483%
# Average training loss after 139 epoch = 0.18885968625545502
# Training accuracy after 139 epoch = 94.13489736070382%
# Val Loss after 139 epochs, loss = 1.515701025724411
# Val Accuracy after 139 epochs = 65.51724137931035%
# Average training loss after 140 epoch = 0.22047401761466806
# Training accuracy after 140 epoch = 92.96187683284457%
# Val Loss after 140 epochs, loss = 1.60264553129673
# Val Accuracy after 140 epochs = 66.37931034482759%
# Average training loss after 141 epoch = 0.18924356925047256
# Training accuracy after 141 epoch = 94.42815249266863%
# Val Loss after 141 epochs, loss = 1.5302926301956177
# Val Accuracy after 141 epochs = 67.24137931034483%
# Average training loss after 142 epoch = 0.23640777509320865
# Training accuracy after 142 epoch = 93.54838709677419%
# Val Loss after 142 epochs, loss = 1.4288391917943954
# Val Accuracy after 142 epochs = 69.82758620689656%
# Average training loss after 143 epoch = 0.20772507244890387
# Training accuracy after 143 epoch = 94.42815249266863%
# Val Loss after 143 epochs, loss = 1.4332534819841385
# Val Accuracy after 143 epochs = 70.6896551724138%
# Average training loss after 144 epoch = 0.2201891460201957
# Training accuracy after 144 epoch = 93.54838709677419%
# Val Loss after 144 epochs, loss = 1.4564329981803894
# Val Accuracy after 144 epochs = 67.24137931034483%
# Average training loss after 145 epoch = 0.13762875646352768
# Training accuracy after 145 epoch = 97.65395894428153%
# Val Loss after 145 epochs, loss = 1.4745583832263947
# Val Accuracy after 145 epochs = 67.24137931034483%
# Average training loss after 146 epoch = 0.21000915528698402
# Training accuracy after 146 epoch = 94.72140762463343%
# Val Loss after 146 epochs, loss = 1.4589522331953049
# Val Accuracy after 146 epochs = 69.82758620689656%
# Average training loss after 147 epoch = 0.21528295156630603
# Training accuracy after 147 epoch = 94.72140762463343%
# Val Loss after 147 epochs, loss = 1.4488582462072372
# Val Accuracy after 147 epochs = 68.10344827586206%
# Average training loss after 148 epoch = 0.21543458849191666
# Training accuracy after 148 epoch = 93.841642228739%
# Val Loss after 148 epochs, loss = 1.465711236000061
# Val Accuracy after 148 epochs = 68.10344827586206%
# Average training loss after 149 epoch = 0.22695397754961794
# Training accuracy after 149 epoch = 93.25513196480938%
# Val Loss after 149 epochs, loss = 1.5627380162477493
# Val Accuracy after 149 epochs = 68.10344827586206%
# Average training loss after 150 epoch = 0.20959437977183948
# Training accuracy after 150 epoch = 94.13489736070382%
# Val Loss after 150 epochs, loss = 1.56193245947361
# Val Accuracy after 150 epochs = 65.51724137931035%
# Average training loss after 151 epoch = 0.23042236810380762
# Training accuracy after 151 epoch = 93.841642228739%
# Val Loss after 151 epochs, loss = 1.626009225845337
# Val Accuracy after 151 epochs = 65.51724137931035%
# Average training loss after 152 epoch = 0.19206342710690064
# Training accuracy after 152 epoch = 94.13489736070382%
# Val Loss after 152 epochs, loss = 1.5826511085033417
# Val Accuracy after 152 epochs = 63.793103448275865%
# Average training loss after 153 epoch = 0.2276972925121134
# Training accuracy after 153 epoch = 92.66862170087975%
# Val Loss after 153 epochs, loss = 1.5700089037418365
# Val Accuracy after 153 epochs = 62.93103448275862%
# Average training loss after 154 epoch = 0.25527849387038837
# Training accuracy after 154 epoch = 90.9090909090909%
# Val Loss after 154 epochs, loss = 1.5112164169549942
# Val Accuracy after 154 epochs = 63.793103448275865%
# Average training loss after 155 epoch = 0.1429237462580204
# Training accuracy after 155 epoch = 95.89442815249268%
# Val Loss after 155 epochs, loss = 1.4745794534683228
# Val Accuracy after 155 epochs = 66.37931034482759%
# Average training loss after 156 epoch = 0.18529059873385864
# Training accuracy after 156 epoch = 95.30791788856305%
# Val Loss after 156 epochs, loss = 1.6128717064857483
# Val Accuracy after 156 epochs = 67.24137931034483%
# Average training loss after 157 epoch = 0.2119059105488387
# Training accuracy after 157 epoch = 92.66862170087975%
# Val Loss after 157 epochs, loss = 1.5834633708000183
# Val Accuracy after 157 epochs = 65.51724137931035%
# Average training loss after 158 epoch = 0.22884602506052365
# Training accuracy after 158 epoch = 92.66862170087975%
# Val Loss after 158 epochs, loss = 1.5866113603115082
# Val Accuracy after 158 epochs = 67.24137931034483%
# Average training loss after 159 epoch = 0.17385925352573395
# Training accuracy after 159 epoch = 95.01466275659824%
# Val Loss after 159 epochs, loss = 1.5850280821323395
# Val Accuracy after 159 epochs = 66.37931034482759%
# Average training loss after 160 epoch = 0.1784290373325348
# Training accuracy after 160 epoch = 94.42815249266863%
# Val Loss after 160 epochs, loss = 1.5349786281585693
# Val Accuracy after 160 epochs = 67.24137931034483%
# Average training loss after 161 epoch = 0.2116318138485605
# Training accuracy after 161 epoch = 94.13489736070382%
# Val Loss after 161 epochs, loss = 1.5625957250595093
# Val Accuracy after 161 epochs = 67.24137931034483%
# Average training loss after 162 epoch = 0.16742649301886559
# Training accuracy after 162 epoch = 94.72140762463343%
# Val Loss after 162 epochs, loss = 1.4877536594867706
# Val Accuracy after 162 epochs = 66.37931034482759%
# Average training loss after 163 epoch = 0.18789259141141718
# Training accuracy after 163 epoch = 94.72140762463343%
# Val Loss after 163 epochs, loss = 1.4449346512556076
# Val Accuracy after 163 epochs = 65.51724137931035%
# Average training loss after 164 epoch = 0.15082746121863072
# Training accuracy after 164 epoch = 95.01466275659824%
# Val Loss after 164 epochs, loss = 1.4029378443956375
# Val Accuracy after 164 epochs = 68.96551724137932%
# Average training loss after 165 epoch = 0.19182747026736086
# Training accuracy after 165 epoch = 95.60117302052787%
# Val Loss after 165 epochs, loss = 1.5186192691326141
# Val Accuracy after 165 epochs = 69.82758620689656%
# Average training loss after 166 epoch = 0.17962586710398848
# Training accuracy after 166 epoch = 95.01466275659824%
# Val Loss after 166 epochs, loss = 1.6114882230758667
# Val Accuracy after 166 epochs = 66.37931034482759%
# Average training loss after 167 epoch = 0.19952382519841194
# Training accuracy after 167 epoch = 94.13489736070382%
# Val Loss after 167 epochs, loss = 1.5809041261672974
# Val Accuracy after 167 epochs = 65.51724137931035%
# Average training loss after 168 epoch = 0.2254990440878001
# Training accuracy after 168 epoch = 92.08211143695014%
# Val Loss after 168 epochs, loss = 1.5860028266906738
# Val Accuracy after 168 epochs = 66.37931034482759%
# Average training loss after 169 epoch = 0.2298123375935988
# Training accuracy after 169 epoch = 92.96187683284457%
# Val Loss after 169 epochs, loss = 1.6059697568416595
# Val Accuracy after 169 epochs = 68.10344827586206%
# Average training loss after 170 epoch = 0.19491805000738663
# Training accuracy after 170 epoch = 93.841642228739%
# Val Loss after 170 epochs, loss = 1.475727453827858
# Val Accuracy after 170 epochs = 67.24137931034483%
# Average training loss after 171 epoch = 0.20490832491354508
# Training accuracy after 171 epoch = 92.96187683284457%
# Val Loss after 171 epochs, loss = 1.4565860629081726
# Val Accuracy after 171 epochs = 64.65517241379311%
# Average training loss after 172 epoch = 0.2001539103009484
# Training accuracy after 172 epoch = 92.37536656891496%
# Val Loss after 172 epochs, loss = 1.503757283091545
# Val Accuracy after 172 epochs = 62.06896551724138%
# Average training loss after 173 epoch = 0.16157956489107825
# Training accuracy after 173 epoch = 95.89442815249268%
# Val Loss after 173 epochs, loss = 1.4419162422418594
# Val Accuracy after 173 epochs = 66.37931034482759%
# Average training loss after 174 epoch = 0.20256502689285713
# Training accuracy after 174 epoch = 93.841642228739%
# Val Loss after 174 epochs, loss = 1.3941765278577805
# Val Accuracy after 174 epochs = 70.6896551724138%
# Average training loss after 175 epoch = 0.1868055510250005
# Training accuracy after 175 epoch = 93.841642228739%
# Val Loss after 175 epochs, loss = 1.4302212446928024
# Val Accuracy after 175 epochs = 68.10344827586206%
# Average training loss after 176 epoch = 0.18641943078149448
# Training accuracy after 176 epoch = 94.13489736070382%
# Val Loss after 176 epochs, loss = 1.4781250357627869
# Val Accuracy after 176 epochs = 66.37931034482759%
# Average training loss after 177 epoch = 0.233477633446455
# Training accuracy after 177 epoch = 92.96187683284457%
# Val Loss after 177 epochs, loss = 1.4203516840934753
# Val Accuracy after 177 epochs = 69.82758620689656%
# Average training loss after 178 epoch = 0.1741095915098082
# Training accuracy after 178 epoch = 94.72140762463343%
# Val Loss after 178 epochs, loss = 1.4580212384462357
# Val Accuracy after 178 epochs = 68.96551724137932%
# Average training loss after 179 epoch = 0.18348830464211377
# Training accuracy after 179 epoch = 93.841642228739%
# Val Loss after 179 epochs, loss = 1.5205641686916351
# Val Accuracy after 179 epochs = 69.82758620689656%
# Average training loss after 180 epoch = 0.19520492242141205
# Training accuracy after 180 epoch = 91.49560117302052%
# Val Loss after 180 epochs, loss = 1.4170914441347122
# Val Accuracy after 180 epochs = 67.24137931034483%
# Average training loss after 181 epoch = 0.2054091114550829
# Training accuracy after 181 epoch = 93.25513196480938%
# Val Loss after 181 epochs, loss = 1.4356314986944199
# Val Accuracy after 181 epochs = 66.37931034482759%
# Average training loss after 182 epoch = 0.17544570328159767
# Training accuracy after 182 epoch = 94.42815249266863%
# Val Loss after 182 epochs, loss = 1.4309293627738953
# Val Accuracy after 182 epochs = 67.24137931034483%
# Average training loss after 183 epoch = 0.2158989350904118
# Training accuracy after 183 epoch = 91.20234604105572%
# Val Loss after 183 epochs, loss = 1.4211821407079697
# Val Accuracy after 183 epochs = 68.10344827586206%
# Average training loss after 184 epoch = 0.17517106167294763
# Training accuracy after 184 epoch = 95.30791788856305%
# Val Loss after 184 epochs, loss = 1.3919203132390976
# Val Accuracy after 184 epochs = 68.96551724137932%
# Average training loss after 185 epoch = 0.2022386288101023
# Training accuracy after 185 epoch = 93.54838709677419%
# Val Loss after 185 epochs, loss = 1.4003189653158188
# Val Accuracy after 185 epochs = 70.6896551724138%
# Average training loss after 186 epoch = 0.16304649920626121
# Training accuracy after 186 epoch = 95.30791788856305%
# Val Loss after 186 epochs, loss = 1.4139907658100128
# Val Accuracy after 186 epochs = 66.37931034482759%
# Average training loss after 187 epoch = 0.1751080687073144
# Training accuracy after 187 epoch = 94.42815249266863%
# Val Loss after 187 epochs, loss = 1.386159747838974
# Val Accuracy after 187 epochs = 68.10344827586206%
# Average training loss after 188 epoch = 0.18663573536005887
# Training accuracy after 188 epoch = 95.60117302052787%
# Val Loss after 188 epochs, loss = 1.4182281643152237
# Val Accuracy after 188 epochs = 68.10344827586206%
# Average training loss after 189 epoch = 0.15976047922264447
# Training accuracy after 189 epoch = 94.72140762463343%
# Val Loss after 189 epochs, loss = 1.4602642953395844
# Val Accuracy after 189 epochs = 68.10344827586206%
# Average training loss after 190 epoch = 0.17588896084238181
# Training accuracy after 190 epoch = 95.01466275659824%
# Val Loss after 190 epochs, loss = 1.3741945624351501
# Val Accuracy after 190 epochs = 67.24137931034483%
# Average training loss after 191 epoch = 0.21617599441246552
# Training accuracy after 191 epoch = 93.54838709677419%
# Val Loss after 191 epochs, loss = 1.4134190082550049
# Val Accuracy after 191 epochs = 65.51724137931035%
# Average training loss after 192 epoch = 0.16994608092037114
# Training accuracy after 192 epoch = 94.72140762463343%
# Val Loss after 192 epochs, loss = 1.3665482550859451
# Val Accuracy after 192 epochs = 68.10344827586206%
# Average training loss after 193 epoch = 0.11929197846488519
# Training accuracy after 193 epoch = 95.01466275659824%
# Val Loss after 193 epochs, loss = 1.3809685707092285
# Val Accuracy after 193 epochs = 68.96551724137932%
# Average training loss after 194 epoch = 0.14661737328225916
# Training accuracy after 194 epoch = 95.30791788856305%
# Val Loss after 194 epochs, loss = 1.3653879314661026
# Val Accuracy after 194 epochs = 69.82758620689656%
# Average training loss after 195 epoch = 0.17883880334821614
# Training accuracy after 195 epoch = 94.72140762463343%
# Val Loss after 195 epochs, loss = 1.4290385097265244
# Val Accuracy after 195 epochs = 66.37931034482759%
# Average training loss after 196 epoch = 0.14280663227493112
# Training accuracy after 196 epoch = 95.30791788856305%
# Val Loss after 196 epochs, loss = 1.4489682018756866
# Val Accuracy after 196 epochs = 68.96551724137932%
# Average training loss after 197 epoch = 0.15544764020226218
# Training accuracy after 197 epoch = 94.72140762463343%
# Val Loss after 197 epochs, loss = 1.3541819006204605
# Val Accuracy after 197 epochs = 67.24137931034483%
# Average training loss after 198 epoch = 0.18054481290958144
# Training accuracy after 198 epoch = 94.13489736070382%
# Val Loss after 198 epochs, loss = 1.4081324934959412
# Val Accuracy after 198 epochs = 67.24137931034483%
# Average training loss after 199 epoch = 0.18892550299113448
# Training accuracy after 199 epoch = 95.30791788856305%
# Val Loss after 199 epochs, loss = 1.4339610189199448
# Val Accuracy after 199 epochs = 67.24137931034483%
# Average training loss after 200 epoch = 0.12647013975815338
# Training accuracy after 200 epoch = 97.0674486803519%
# Val Loss after 200 epochs, loss = 1.432672142982483
# Val Accuracy after 200 epochs = 69.82758620689656%
# Average training loss after 201 epoch = 0.1484046449715441
# Training accuracy after 201 epoch = 95.01466275659824%
# Val Loss after 201 epochs, loss = 1.5312456041574478
# Val Accuracy after 201 epochs = 65.51724137931035%
# Average training loss after 202 epoch = 0.17060580104589462
# Training accuracy after 202 epoch = 94.72140762463343%
# Val Loss after 202 epochs, loss = 1.641507774591446
# Val Accuracy after 202 epochs = 64.65517241379311%
# Average training loss after 203 epoch = 0.12635751305655998
# Training accuracy after 203 epoch = 96.48093841642229%
# Val Loss after 203 epochs, loss = 1.6480482518672943
# Val Accuracy after 203 epochs = 67.24137931034483%
# Average training loss after 204 epoch = 0.14445858482610097
# Training accuracy after 204 epoch = 95.60117302052787%
# Val Loss after 204 epochs, loss = 1.4976355582475662
# Val Accuracy after 204 epochs = 68.96551724137932%
# Average training loss after 205 epoch = 0.21831987527283755
# Training accuracy after 205 epoch = 92.66862170087975%
# Val Loss after 205 epochs, loss = 1.497965395450592
# Val Accuracy after 205 epochs = 66.37931034482759%
# Average training loss after 206 epoch = 0.17017583345825021
# Training accuracy after 206 epoch = 94.72140762463343%
# Val Loss after 206 epochs, loss = 1.6088117361068726
# Val Accuracy after 206 epochs = 67.24137931034483%
# Average training loss after 207 epoch = 0.1818536161021753
# Training accuracy after 207 epoch = 93.841642228739%
# Val Loss after 207 epochs, loss = 1.6823641210794449
# Val Accuracy after 207 epochs = 62.93103448275862%
# Average training loss after 208 epoch = 0.17801145972176033
# Training accuracy after 208 epoch = 93.841642228739%
# Val Loss after 208 epochs, loss = 1.64491868019104
# Val Accuracy after 208 epochs = 60.3448275862069%
# Average training loss after 209 epoch = 0.1914615702222694
# Training accuracy after 209 epoch = 93.841642228739%
# Val Loss after 209 epochs, loss = 1.7214051634073257
# Val Accuracy after 209 epochs = 64.65517241379311%
# Average training loss after 210 epoch = 0.1948105405000123
# Training accuracy after 210 epoch = 92.96187683284457%
# Val Loss after 210 epochs, loss = 1.608372151851654
# Val Accuracy after 210 epochs = 63.793103448275865%
# Average training loss after 211 epoch = 0.17002545601942323
# Training accuracy after 211 epoch = 94.42815249266863%
# Val Loss after 211 epochs, loss = 1.610308587551117
# Val Accuracy after 211 epochs = 64.65517241379311%
# Average training loss after 212 epoch = 0.154800222678618
# Training accuracy after 212 epoch = 95.30791788856305%
# Val Loss after 212 epochs, loss = 1.6931981295347214
# Val Accuracy after 212 epochs = 63.793103448275865%
# Average training loss after 213 epoch = 0.16088530082594266
# Training accuracy after 213 epoch = 94.42815249266863%
# Val Loss after 213 epochs, loss = 1.7260758429765701
# Val Accuracy after 213 epochs = 62.93103448275862%
# Average training loss after 214 epoch = 0.2088357528502291
# Training accuracy after 214 epoch = 93.25513196480938%
# Val Loss after 214 epochs, loss = 1.5812195092439651
# Val Accuracy after 214 epochs = 66.37931034482759%
# Average training loss after 215 epoch = 0.14296530195596543
# Training accuracy after 215 epoch = 95.30791788856305%
# Val Loss after 215 epochs, loss = 1.5769699662923813
# Val Accuracy after 215 epochs = 67.24137931034483%
# Average training loss after 216 epoch = 0.16932196678085762
# Training accuracy after 216 epoch = 95.30791788856305%
# Val Loss after 216 epochs, loss = 1.5655989199876785
# Val Accuracy after 216 epochs = 66.37931034482759%
# Average training loss after 217 epoch = 0.151875742118467
# Training accuracy after 217 epoch = 95.30791788856305%
# Val Loss after 217 epochs, loss = 1.6079186797142029
# Val Accuracy after 217 epochs = 66.37931034482759%
# Average training loss after 218 epoch = 0.17118992419405418
# Training accuracy after 218 epoch = 94.72140762463343%
# Val Loss after 218 epochs, loss = 1.5346530079841614
# Val Accuracy after 218 epochs = 67.24137931034483%
# Average training loss after 219 epoch = 0.16775879738005725
# Training accuracy after 219 epoch = 93.54838709677419%
# Val Loss after 219 epochs, loss = 1.5714279413223267
# Val Accuracy after 219 epochs = 67.24137931034483%
# Average training loss after 220 epoch = 0.16056858477267352
# Training accuracy after 220 epoch = 94.42815249266863%
# Val Loss after 220 epochs, loss = 1.5897789150476456
# Val Accuracy after 220 epochs = 66.37931034482759%
# Average training loss after 221 epoch = 0.1839113740081137
# Training accuracy after 221 epoch = 94.13489736070382%
# Val Loss after 221 epochs, loss = 1.6084912866353989
# Val Accuracy after 221 epochs = 67.24137931034483%
# Average training loss after 222 epoch = 0.1715713238174265
# Training accuracy after 222 epoch = 94.42815249266863%
# Val Loss after 222 epochs, loss = 1.5746791809797287
# Val Accuracy after 222 epochs = 68.10344827586206%
# Average training loss after 223 epoch = 0.21095198680731383
# Training accuracy after 223 epoch = 94.72140762463343%
# Val Loss after 223 epochs, loss = 1.535499706864357
# Val Accuracy after 223 epochs = 67.24137931034483%
# Average training loss after 224 epoch = 0.1765290249816396
# Training accuracy after 224 epoch = 94.72140762463343%
# Val Loss after 224 epochs, loss = 1.441201850771904
# Val Accuracy after 224 epochs = 67.24137931034483%
# Average training loss after 225 epoch = 0.1256386602128094
# Training accuracy after 225 epoch = 96.18768328445748%
# Val Loss after 225 epochs, loss = 1.4442744702100754
# Val Accuracy after 225 epochs = 67.24137931034483%
# Average training loss after 226 epoch = 0.13634818013418804
# Training accuracy after 226 epoch = 95.60117302052787%
# Val Loss after 226 epochs, loss = 1.4120688736438751
# Val Accuracy after 226 epochs = 67.24137931034483%
# Average training loss after 227 epoch = 0.14053691652688113
# Training accuracy after 227 epoch = 95.60117302052787%
# Val Loss after 227 epochs, loss = 1.4120554625988007
# Val Accuracy after 227 epochs = 68.96551724137932%
# Average training loss after 228 epoch = 0.17115418342026797
# Training accuracy after 228 epoch = 95.01466275659824%
# Val Loss after 228 epochs, loss = 1.4427320510149002
# Val Accuracy after 228 epochs = 68.96551724137932%
# Average training loss after 229 epoch = 0.15531645410440184
# Training accuracy after 229 epoch = 95.89442815249268%
# Val Loss after 229 epochs, loss = 1.4768613427877426
# Val Accuracy after 229 epochs = 68.10344827586206%
# Average training loss after 230 epoch = 0.1543237180872397
# Training accuracy after 230 epoch = 95.01466275659824%
# Val Loss after 230 epochs, loss = 1.5446954667568207
# Val Accuracy after 230 epochs = 65.51724137931035%
# Average training loss after 231 epoch = 0.10196173292669383
# Training accuracy after 231 epoch = 97.0674486803519%
# Val Loss after 231 epochs, loss = 1.5595883280038834
# Val Accuracy after 231 epochs = 65.51724137931035%
# Average training loss after 232 epoch = 0.1459253809668801
# Training accuracy after 232 epoch = 95.60117302052787%
# Val Loss after 232 epochs, loss = 1.514117181301117
# Val Accuracy after 232 epochs = 65.51724137931035%
# Average training loss after 233 epoch = 0.12018837982958014
# Training accuracy after 233 epoch = 96.18768328445748%
# Val Loss after 233 epochs, loss = 1.500170961022377
# Val Accuracy after 233 epochs = 66.37931034482759%
# Average training loss after 234 epoch = 0.16184272278438916
# Training accuracy after 234 epoch = 95.30791788856305%
# Val Loss after 234 epochs, loss = 1.475702092051506
# Val Accuracy after 234 epochs = 66.37931034482759%
# Average training loss after 235 epoch = 0.1298466141928326
# Training accuracy after 235 epoch = 95.30791788856305%
# Val Loss after 235 epochs, loss = 1.4382315278053284
# Val Accuracy after 235 epochs = 65.51724137931035%
# Average training loss after 236 epoch = 0.1279161980544979
# Training accuracy after 236 epoch = 95.60117302052787%
# Val Loss after 236 epochs, loss = 1.489774003624916
# Val Accuracy after 236 epochs = 67.24137931034483%
# Average training loss after 237 epoch = 0.12553011761470276
# Training accuracy after 237 epoch = 95.89442815249268%
# Val Loss after 237 epochs, loss = 1.4898377656936646
# Val Accuracy after 237 epochs = 65.51724137931035%
# Average training loss after 238 epoch = 0.13668277724222702
# Training accuracy after 238 epoch = 96.18768328445748%
# Val Loss after 238 epochs, loss = 1.4701857268810272
# Val Accuracy after 238 epochs = 64.65517241379311%
# Average training loss after 239 epoch = 0.1313654575496912
# Training accuracy after 239 epoch = 96.48093841642229%
# Val Loss after 239 epochs, loss = 1.4531878530979156
# Val Accuracy after 239 epochs = 64.65517241379311%
# Average training loss after 240 epoch = 0.11987140706994316
# Training accuracy after 240 epoch = 96.48093841642229%
# Val Loss after 240 epochs, loss = 1.4319028556346893
# Val Accuracy after 240 epochs = 66.37931034482759%
# Average training loss after 241 epoch = 0.14345775654708798
# Training accuracy after 241 epoch = 95.60117302052787%
# Val Loss after 241 epochs, loss = 1.40136057138443
# Val Accuracy after 241 epochs = 67.24137931034483%
# Average training loss after 242 epoch = 0.14390921203250234
# Training accuracy after 242 epoch = 95.89442815249268%
# Val Loss after 242 epochs, loss = 1.4451532065868378
# Val Accuracy after 242 epochs = 62.93103448275862%
# Average training loss after 243 epoch = 0.12731089883229949
# Training accuracy after 243 epoch = 95.30791788856305%
# Val Loss after 243 epochs, loss = 1.4690798968076706
# Val Accuracy after 243 epochs = 66.37931034482759%
# Average training loss after 244 epoch = 0.161524833264676
# Training accuracy after 244 epoch = 94.13489736070382%
# Val Loss after 244 epochs, loss = 1.4838029891252518
# Val Accuracy after 244 epochs = 68.10344827586206%
# Average training loss after 245 epoch = 0.13622063432227483
# Training accuracy after 245 epoch = 94.72140762463343%
# Val Loss after 245 epochs, loss = 1.4904759377241135
# Val Accuracy after 245 epochs = 66.37931034482759%
# Average training loss after 246 epoch = 0.1511088961904699
# Training accuracy after 246 epoch = 95.30791788856305%
# Val Loss after 246 epochs, loss = 1.5534028857946396
# Val Accuracy after 246 epochs = 65.51724137931035%
# Average training loss after 247 epoch = 0.11632891744375229
# Training accuracy after 247 epoch = 96.18768328445748%
# Val Loss after 247 epochs, loss = 1.5777015089988708
# Val Accuracy after 247 epochs = 69.82758620689656%
# Average training loss after 248 epoch = 0.18753094564784656
# Training accuracy after 248 epoch = 95.60117302052787%
# Val Loss after 248 epochs, loss = 1.5340745598077774
# Val Accuracy after 248 epochs = 68.10344827586206%
# Average training loss after 249 epoch = 0.12109480764378201
# Training accuracy after 249 epoch = 96.18768328445748%
# Val Loss after 249 epochs, loss = 1.5418356359004974
# Val Accuracy after 249 epochs = 66.37931034482759%
# Average training loss after 250 epoch = 0.1642415909604593
# Training accuracy after 250 epoch = 94.42815249266863%
# Val Loss after 250 epochs, loss = 1.5172830671072006
# Val Accuracy after 250 epochs = 67.24137931034483%

# %%
print('Best accuracy after {} epochs = {}'.format(epoch+1, min_accuracy))
# Out:
# Best accuracy after 250 epochs = 70.6896551724138
